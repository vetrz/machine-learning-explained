# %%
from ucimlrepo import fetch_ucirepo

# %%
adult = fetch_ucirepo(id=2)

# %%
df = adult.data.features

# %%
df["income"] = adult.data.targets

# %%
df.to_csv("./data/rawadult_raw.csv", index=False)
