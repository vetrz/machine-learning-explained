# %%
import pandas as pd

# %%
df_training_features = pd.read_csv("../data/base/training_set_features.csv")
df_training_targets = pd.read_csv("../data/base/training_set_labels.csv")

# %%
df = df_training_features.merge(df_training_targets, on="respondent_id")

# %%
df.to_csv("../data/raw/training_set.csv", index=False)
